# %%
import os
import sys
import mne
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(color_codes=True)
from scipy.signal import welch, firwin, filtfilt, hilbert
from time import gmtime

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sys.path.insert(0, '/Users/wassilyminkow/Scripts/Python3/')

from Neuroinformatics.torpor_project.data import *
from Neuroinformatics.math.pandas.statistics import *
from Neuroinformatics.data.pandas.time_series import TimeSeries
from Neuroinformatics.math.curves import *
from Neuroinformatics.math.regression import *

# %%
pylab.rcParams['figure.figsize'] = (22, 18)
sns.set(font_scale=2.5)

# %%
eeg_path = "/Users/wassilyminkow/Data/NakedMoleRat_Data/csv/"

# %%
corr = "Negative"

for subject in os.listdir(eeg_path):
    
    data = pd.read_csv(eeg_path + subject)

    gap = 6*12
    temperature = np.asanyarray(((data["dG"]).rolling(gap).mean().dropna()))
    acceleration = np.asanyarray(((data["T"]).rolling(gap).mean().dropna()))
    time_array = np.asanyarray(data.index[:temperature.shape[0]])/6/24
    z = moving_correlation(time_array, temperature, acceleration, gap=6*12, correlation=corr.lower())
    
    top = np.max([(standardize(temperature)).max(), (standardize(acceleration)).max()])
    bottom = np.min([(standardize(temperature)).min(), (standardize(acceleration)).min()])
    skip_start = 0

    tech = np.ones(z[0][1][:].shape[0])
    name = subject.split(".")[0]

    plt.fill_between(z[2][1][:], tech*top, tech*bottom, alpha=0.5, facecolor="mistyrose", label = f"90% > {corr} Spearman Correlation > 85%")
    plt.fill_between(z[1][1][:], tech*top, tech*bottom, alpha=0.5, facecolor="lemonchiffon", label = f"95% > {corr} Spearman Correlation > 90 %")
    plt.fill_between(z[0][1][:], tech*top, tech*bottom, alpha=0.5, facecolor="lightgreen", label = f"{corr} Spearman Correlation > 95 %")
    plt.plot(time_array, standardize(temperature), label="Body Temperature Trend")
    plt.plot(time_array, standardize(acceleration), label="Acceleration Trend")
    plt.title(f"Subject: {name}\nBody Temperature And Acceleration Trends \nSignificant (p < 1e-6) Moving Correlation (Window = 12 Hours)")
    plt.ylabel("Standartized Values")
    plt.xlabel("Time (Days)")
    plt.legend(loc="best")
    plt.xlim([0, 29])
    plt.show()
