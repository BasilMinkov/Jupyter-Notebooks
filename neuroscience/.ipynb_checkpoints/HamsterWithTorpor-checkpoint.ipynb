# %%
import os
import sys
import mne
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(color_codes=True)
from scipy.signal import welch, firwin, filtfilt, hilbert
from scipy.stats.stats import pearsonr, spearmanr
from scipy.stats import chi2_contingency
from sklearn.preprocessing import normalize 
from time import gmtime
from statsmodels.sandbox.stats.multicomp import multipletests
from sklearn.cluster import KMeans
from scipy.stats import wilcoxon

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sys.path.insert(0, '/Users/wassilyminkow/Scripts/Python3/')

from Neuroinformatics.torpor_project.data import *
from Neuroinformatics.math.pandas.statistics import *
from Neuroinformatics.data.pandas.time_series import TimeSeries
from Neuroinformatics.math.curves import *
from Neuroinformatics.math.regression import *

# %%
pylab.rcParams['figure.figsize'] = (22, 18)
sns.set(font_scale=2.5)

# %%
path = "/Users/wassilyminkow/Data/Hamster_Data/hamster_with_torpor/25-12-2017_17-24_torpor_starts/"
files = [
    "2017/25-12-2017_17-24.bdf",
    "2017/29-12-2017_16-18.bdf",
    "2018/02-01-2018_19-06.bdf",
    "2018/06-01-2018_18-33.bdf",
    "2018/06-01-2018_18-33.bdf",
    "2018/10-01-2018_15-09.bdf",
    "2018/13-01-2018_19-37.bdf",
    "2018/15-01-2018_18-07.bdf",
]

# %%
path = "/Users/wassilyminkow/Data/Hamster_Data/hamster_with_torpor/25-12-2017_17-24_torpor_starts/2017/25-12-2017_17-24_scoring/"
files = os.listdir(path)

# %%
files
# Out:
# ['2017/25-12-2017_17-24.bdf',
#  '2017/29-12-2017_16-18.bdf',
#  '2018/02-01-2018_19-06.bdf',
#  '2018/06-01-2018_18-33.bdf',
#  '2018/06-01-2018_18-33.bdf',
#  '2018/10-01-2018_15-09.bdf',
#  '2018/13-01-2018_19-37.bdf',
#  '2018/15-01-2018_18-07.bdf']

# %%
raw_data = mne.io.read_raw_edf(path+files[0])
# Out:
# Extracting EDF parameters from /Users/wassilyminkow/Data/Hamster_Data/hamster_with_torpor/25-12-2017_17-24_torpor_starts/2017/25-12-2017_17-24.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# <ipython-input-6-c5bbcdc3e70a>:1: RuntimeWarning: Interpolating stim channel. Events may jitter.
#   raw_data = mne.io.read_raw_edf(path+files[0])

# %%
raw_data.info
# Out:
# <Info | 16 non-empty fields
#     bads : list | 0 items
#     ch_names : list | Channel 1, Channel 2, Accelerometer X, Accelerometer Y, STI 014
#     chs : list | 5 items (EEG: 4, STIM: 1)
#     comps : list | 0 items
#     custom_ref_applied : bool | False
#     dev_head_t : Transform | 3 items
#     events : list | 0 items
#     highpass : float | 0.0 Hz
#     hpi_meas : list | 0 items
#     hpi_results : list | 0 items
#     lowpass : float | 125.05127102111867 Hz
#     meas_date : tuple | 2017-12-25 17:24:50 GMT
#     nchan : int | 5
#     proc_history : list | 0 items
#     projs : list | 0 items
#     sfreq : float | 250.10254204223733 Hz
#     acq_pars : NoneType
#     acq_stim : NoneType
#     ctf_head_t : NoneType
#     description : NoneType
#     dev_ctf_t : NoneType
#     dig : NoneType
#     experimenter : NoneType
#     file_id : NoneType
#     gantry_angle : NoneType
#     hpi_subsystem : NoneType
#     kit_system_id : NoneType
#     line_freq : NoneType
#     meas_id : NoneType
#     proj_id : NoneType
#     proj_name : NoneType
#     subject_info : NoneType
#     xplotter_layout : NoneType
# >

# %%
signal = raw_data.get_data(0)

# %%
signal.shape[1]
# Out:
# 83964000

# %%
plt.plot(signal[:100])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-1ad250673460> in <module>
# ----> 1 plt.plot(signal[:100])
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1609         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1610
# -> 1611         for line in self._get_lines(*args, **kwargs):
#    1612             self.add_line(line)
#    1613             lines.append(line)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     381                                   "with non-matching shapes is deprecated.")
#     382         for j in range(max(ncx, ncy)):
# --> 383             seg = func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     384             ret.append(seg)
#     385         return ret
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _makeline(self, x, y, kw, kwargs)
#     286         default_dict = self._getdefaults(None, kw)
#     287         self._setdefaults(default_dict, kw)
# --> 288         seg = mlines.Line2D(x, y, **kw)
#     289         return seg
#     290
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     309
#     310         """
# --> 311         Artist.__init__(self)
#     312
#     313         #convert sequences to numpy arrays
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in __init__(self)
#     104         self._propobservers = {}  # a dict from oids to funcs
#     105         try:
# --> 106             self.axes = None
#     107         except AttributeError:
#     108             # Handle self.axes as a read-only property, as in Figure.
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/lines.py in axes(self, ax)
#     609         # call the set method from the base-class property
#     610         Artist.axes.fset(self, ax)
# --> 611         if ax is not None:
#     612             # connect unit-related callbacks
#     613             if ax.xaxis is not None:
#
# KeyboardInterrupt:

# %%
def skip_damaged_epoch(start_time):
    """
    """
    
    n_skip = 0
    
    # skip seconds
    
    if start_time[5] > 0:
        n_skip += (60-start_time[5])*fs
        
        start_time[5] = 0
        start_time[4] += 1
        
    # skip minutes
    
    dummy = str(start_time[4])
    
    if len(dummy) == 2:
        ones = int(dummy[1])
        tens = int(dummy[0])
    else:
        ones = int(dummy[0])
        tens = 0
    
    if ones > 0:
        n_skip += (10-ones)*fs*60
        
        if tens == 5:
            start_time[4] = 0
            start_time[3] += 1
        else:
            start_time[4] += (10-ones) #TODO 
    
    return n_skip

# %%
temp = pd.read_csv("/Users/wassilyminkow/Data/Hamster_Data/hamster_with_torpor/RatTemperature.csv", sep=",")
temp["Power 1 - 4 Hz"] = np.nan 
temp["Power 4 - 8 Hz"] = np.nan 
temp["Power"] = np.nan 
temp["Acceleration"] = np.nan 
    
path = "/Users/wassilyminkow/Data/Hamster_Data/hamster_with_torpor/25-12-2017_17-24_torpor_starts/"
files = [
    "2017/25-12-2017_17-24.bdf",
    "2017/29-12-2017_16-18.bdf",
    "2018/02-01-2018_19-06.bdf",
    "2018/06-01-2018_18-33.bdf",
    "2018/06-01-2018_18-33.bdf",
    "2018/10-01-2018_15-09.bdf",
    "2018/13-01-2018_19-37.bdf",
]
    
fs = 250
    
for file in files:
    
    # read EEG and acceleration data
    raw_data = mne.io.read_raw_edf(path+file)
    df = pd.DataFrame(raw_data.get_data([0, 2]), index=[raw_data.ch_names[0], raw_data.ch_names[2]]).T
    
    start = list(gmtime(raw_data.info['meas_date'][0]))
    
    n_skip = skip_damaged_epoch(start)
    
    df_new = df.iloc[n_skip:, ]
    
    n_epocs = int(np.floor(df_new.shape[0]/fs/60/10))
    n_samples = int(n_epocs*10*60*fs)
    
    df_epocs = df_new.iloc[:n_samples, :]
    
    start_epoc = temp[(temp['Year']==start[0])&(temp['Month']==start[1])&(temp['Day']==start[2])&(temp['Hour']==start[3])&(temp['Minute']==start[4])].index[0]
    
    temp_epocs = temp.iloc[start_epoc:start_epoc+n_epocs, -1]
    
    n_slises = 20
    step = fs*60*10

    order = 400 # filter order
    a = 1 

    band = np.array([1, 4])    
    b = firwin(order, band * 2 / fs, width=None, window='hamming', pass_zero=False)  # design filter
    df_epocs_low = filtfilt(b, a, df_epocs.iloc[:, 0]) # apply filter

    band = np.array([4, 8])    
    b = firwin(order, band * 2 / fs, width=None, window='hamming', pass_zero=False)  # design filter
    df_epocs_hi = filtfilt(b, a, df_epocs.iloc[:, 0])

    sum_power_low = np.array(list(map(lambda i: (df_epocs_low[i*step:(i+1)*step]**2).mean(), np.arange(n_epocs))))
    sum_power_hi = np.array(list(map(lambda i: (df_epocs_hi[i*step:(i+1)*step]**2).mean(), np.arange(n_epocs))))
    sum_power = np.array(list(map(lambda i: (df_epocs.iloc[i*step:(i+1)*step, 0]**2).mean(), np.arange(n_epocs))))
    sum_a = np.array(list(map(lambda i: (np.abs(df_epocs.iloc[i*step:(i+1)*step, 1]-df_epocs.iloc[i*step:(i+1)*step, 1].mean())).mean(), np.arange(n_epocs))))

    temp.iloc[start_epoc:start_epoc+n_epocs,-4] = sum_power_low*1e3
    temp.iloc[start_epoc:start_epoc+n_epocs,-3] = sum_power_hi*1e3
    temp.iloc[start_epoc:start_epoc+n_epocs,-2] = sum_power*1e3
    temp.iloc[start_epoc:start_epoc+n_epocs,-1] = sum_a*1e-1

    del df_epocs_low, df_epocs_hi, sum_power_low, sum_power_hi, sum_power, sum_a, raw_data, df, df_new
# Out:
# Extracting EDF parameters from /Users/wassilyminkow/Data/Hamster_Data/hamster_with_torpor/25-12-2017_17-24_torpor_starts/2017/25-12-2017_17-24.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# <ipython-input-8-890287bcf35f>:23: RuntimeWarning: Interpolating stim channel. Events may jitter.
#   raw_data = mne.io.read_raw_edf(path+file)
# Extracting EDF parameters from /Users/wassilyminkow/Data/Hamster_Data/hamster_with_torpor/25-12-2017_17-24_torpor_starts/2017/29-12-2017_16-18.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# <ipython-input-8-890287bcf35f>:23: RuntimeWarning: Interpolating stim channel. Events may jitter.
#   raw_data = mne.io.read_raw_edf(path+file)
# Extracting EDF parameters from /Users/wassilyminkow/Data/Hamster_Data/hamster_with_torpor/25-12-2017_17-24_torpor_starts/2018/02-01-2018_19-06.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# <ipython-input-8-890287bcf35f>:23: RuntimeWarning: Interpolating stim channel. Events may jitter.
#   raw_data = mne.io.read_raw_edf(path+file)
# Extracting EDF parameters from /Users/wassilyminkow/Data/Hamster_Data/hamster_with_torpor/25-12-2017_17-24_torpor_starts/2018/06-01-2018_18-33.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# <ipython-input-8-890287bcf35f>:23: RuntimeWarning: Interpolating stim channel. Events may jitter.
#   raw_data = mne.io.read_raw_edf(path+file)
# Extracting EDF parameters from /Users/wassilyminkow/Data/Hamster_Data/hamster_with_torpor/25-12-2017_17-24_torpor_starts/2018/06-01-2018_18-33.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# <ipython-input-8-890287bcf35f>:23: RuntimeWarning: Interpolating stim channel. Events may jitter.
#   raw_data = mne.io.read_raw_edf(path+file)
# Extracting EDF parameters from /Users/wassilyminkow/Data/Hamster_Data/hamster_with_torpor/25-12-2017_17-24_torpor_starts/2018/10-01-2018_15-09.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# <ipython-input-8-890287bcf35f>:23: RuntimeWarning: Interpolating stim channel. Events may jitter.
#   raw_data = mne.io.read_raw_edf(path+file)
# Extracting EDF parameters from /Users/wassilyminkow/Data/Hamster_Data/hamster_with_torpor/25-12-2017_17-24_torpor_starts/2018/13-01-2018_19-37.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# <ipython-input-8-890287bcf35f>:23: RuntimeWarning: Interpolating stim channel. Events may jitter.
#   raw_data = mne.io.read_raw_edf(path+file)

# %%
time_array = temp.dropna().index/6/24

# %%
temp['Temperature'] += 273.15

# %%
temp
# Out:
#       Page  Record  Period  Year  Month  Day  Hour  Minute  Second  Ubat  \
# 0      132      25      10  2017     12   25     0       0       0   3.0
# 1      132      26      10  2017     12   25     0      10       0   3.0
# 2      132      27      10  2017     12   25     0      20       0   3.0
# 3      132      28      10  2017     12   25     0      30       0   3.0
# 4      133       1      10  2017     12   25     0      40       0   3.0
# 5      133       2      10  2017     12   25     0      50       0   3.0
# 6      133       3      10  2017     12   25     1       0       0   3.0
# 7      133       4      10  2017     12   25     1      10       0   3.0
# 8      133       5      10  2017     12   25     1      20       0   3.0
# 9      133       6      10  2017     12   25     1      30       0   3.0
# 10     133       7      10  2017     12   25     1      40       0   3.0
# 11     133       8      10  2017     12   25     1      50       0   3.0
# 12     133       9      10  2017     12   25     2       0       0   3.0
# 13     133      10      10  2017     12   25     2      10       0   3.0
# 14     133      11      10  2017     12   25     2      20       0   3.0
# 15     133      12      10  2017     12   25     2      30       0   3.0
# 16     133      13      10  2017     12   25     2      40       0   3.0
# 17     133      14      10  2017     12   25     2      50       0   3.0
# 18     133      15      10  2017     12   25     3       0       0   3.0
# 19     133      16      10  2017     12   25     3      10       0   3.0
# 20     133      17      10  2017     12   25     3      20       0   3.0
# 21     133      18      10  2017     12   25     3      30       0   3.0
# 22     133      19      10  2017     12   25     3      40       0   3.0
# 23     133      20      10  2017     12   25     3      50       0   3.0
# 24     133      21      10  2017     12   25     4       0       0   3.0
# 25     133      22      10  2017     12   25     4      10       0   3.0
# 26     133      23      10  2017     12   25     4      20       0   3.0
# 27     133      24      10  2017     12   25     4      30       0   3.0
# 28     133      25      10  2017     12   25     4      40       0   3.0
# 29     133      26      10  2017     12   25     4      50       0   3.0
# ...    ...     ...     ...   ...    ...  ...   ...     ...     ...   ...
# 3260   249       9      10  2018      1   16    15      20       0   2.9
# 3261   249      10      10  2018      1   16    15      30       0   2.9
# 3262   249      11      10  2018      1   16    15      40       0   2.9
# 3263   249      12      10  2018      1   16    15      50       0   2.9
# 3264   249      13      10  2018      1   16    16       0       0   2.9
# 3265   249      14      10  2018      1   16    16      10       0   2.9
# 3266   249      15      10  2018      1   16    16      20       0   2.9
# 3267   249      16      10  2018      1   16    16      30       0   2.9
# 3268   249      17      10  2018      1   16    16      40       0   2.9
# 3269   249      18      10  2018      1   16    16      50       0   2.9
# 3270   249      19      10  2018      1   16    17       0       0   2.9
# 3271   249      20      10  2018      1   16    17      10       0   2.9
# 3272   249      21      10  2018      1   16    17      20       0   2.9
# 3273   249      22      10  2018      1   16    17      30       0   2.9
# 3274   249      23      10  2018      1   16    17      40       0   2.9
# 3275   249      24      10  2018      1   16    17      50       0   2.9
# 3276   249      25      10  2018      1   16    18       0       0   2.9
# 3277   249      26      10  2018      1   16    18      10       0   2.9
# 3278   249      27      10  2018      1   16    18      20       0   2.9
# 3279   249      28      10  2018      1   16    18      30       0   2.9
# 3280   250       1      10  2018      1   16    18      40       0   2.9
# 3281   250       2      10  2018      1   16    18      50       0   2.9
# 3282   250       3      10  2018      1   16    19       0       0   2.9
# 3283   250       4      10  2018      1   16    19      10       0   2.9
# 3284   250       5      10  2018      1   16    19      20       0   2.9
# 3285   250       6      10  2018      1   16    19      30       0   2.9
# 3286   250       7      10  2018      1   16    19      40       0   2.9
# 3287   250       8      10  2018      1   16    19      50       0   2.9
# 3288   250       9      10  2018      1   16    20       0       0   2.9
# 3289   250      10      10  2018      1   16    20      10       0   2.9
#
#       Temperature  Power 1 - 4 Hz  Power 4 - 8 Hz  Power  Acceleration
# 0          36.228             NaN             NaN    NaN           NaN
# 1          36.549             NaN             NaN    NaN           NaN
# 2          36.493             NaN             NaN    NaN           NaN
# 3          36.455             NaN             NaN    NaN           NaN
# 4          36.534             NaN             NaN    NaN           NaN
# 5          36.553             NaN             NaN    NaN           NaN
# 6          36.673             NaN             NaN    NaN           NaN
# 7          36.434             NaN             NaN    NaN           NaN
# 8          36.201             NaN             NaN    NaN           NaN
# 9          36.339             NaN             NaN    NaN           NaN
# 10         36.673             NaN             NaN    NaN           NaN
# 11         36.905             NaN             NaN    NaN           NaN
# 12         36.824             NaN             NaN    NaN           NaN
# 13         37.019             NaN             NaN    NaN           NaN
# 14         37.182             NaN             NaN    NaN           NaN
# 15         37.415             NaN             NaN    NaN           NaN
# 16         37.629             NaN             NaN    NaN           NaN
# 17         37.560             NaN             NaN    NaN           NaN
# 18         37.547             NaN             NaN    NaN           NaN
# 19         37.396             NaN             NaN    NaN           NaN
# 20         37.258             NaN             NaN    NaN           NaN
# 21         37.321             NaN             NaN    NaN           NaN
# 22         37.063             NaN             NaN    NaN           NaN
# 23         37.012             NaN             NaN    NaN           NaN
# 24         36.899             NaN             NaN    NaN           NaN
# 25         36.905             NaN             NaN    NaN           NaN
# 26         36.868             NaN             NaN    NaN           NaN
# 27         37.038             NaN             NaN    NaN           NaN
# 28         36.824             NaN             NaN    NaN           NaN
# 29         36.950             NaN             NaN    NaN           NaN
# ...           ...             ...             ...    ...           ...
# 3260        8.860             NaN             NaN    NaN           NaN
# 3261        8.828             NaN             NaN    NaN           NaN
# 3262        8.840             NaN             NaN    NaN           NaN
# 3263        8.853             NaN             NaN    NaN           NaN
# 3264        8.840             NaN             NaN    NaN           NaN
# 3265        8.866             NaN             NaN    NaN           NaN
# 3266        8.872             NaN             NaN    NaN           NaN
# 3267        8.866             NaN             NaN    NaN           NaN
# 3268        8.892             NaN             NaN    NaN           NaN
# 3269        8.898             NaN             NaN    NaN           NaN
# 3270        8.904             NaN             NaN    NaN           NaN
# 3271        8.904             NaN             NaN    NaN           NaN
# 3272        8.911             NaN             NaN    NaN           NaN
# 3273        8.898             NaN             NaN    NaN           NaN
# 3274        8.898             NaN             NaN    NaN           NaN
# 3275        8.911             NaN             NaN    NaN           NaN
# 3276        8.930             NaN             NaN    NaN           NaN
# 3277        8.930             NaN             NaN    NaN           NaN
# 3278        8.962             NaN             NaN    NaN           NaN
# 3279        8.987             NaN             NaN    NaN           NaN
# 3280        8.994             NaN             NaN    NaN           NaN
# 3281        9.006             NaN             NaN    NaN           NaN
# 3282        9.000             NaN             NaN    NaN           NaN
# 3283        8.994             NaN             NaN    NaN           NaN
# 3284        8.981             NaN             NaN    NaN           NaN
# 3285        8.974             NaN             NaN    NaN           NaN
# 3286        8.974             NaN             NaN    NaN           NaN
# 3287        8.962             NaN             NaN    NaN           NaN
# 3288        8.968             NaN             NaN    NaN           NaN
# 3289        8.955             NaN             NaN    NaN           NaN
#
# [3290 rows x 15 columns]

# %%
plt.plot(time_array, temp.dropna().iloc[:, -5], label="Body Temperature")
plt.plot(time_array, temp.dropna().iloc[:, -2], label="Relative EEG Signal Power", color="C4")
plt.plot(time_array, temp.dropna().iloc[:, -1], label="Relative Movement Speed")

# plt.ylim([0, 40])
plt.title("EEG power, body temperature and movement speed")
plt.ylabel(r"$t^o C$")
plt.xlabel("Time (Day)")
plt.legend(prop={'size': 25})
plt.show()

# %%
time_array = temp.dropna().index/6/24

skip_start = 1250
skip_end = 1900

plt.subplot(2, 1, 1)

plt.plot(time_array[:skip_start], temp.dropna().iloc[:skip_start, -5], label="Body Temperature") 
plt.plot(time_array[:skip_start], temp.dropna().iloc[:skip_start, -2], label="Relative EEG Signal Power", color="C4")
plt.plot(time_array[:skip_start], temp.dropna().iloc[:skip_start, -1], label="Относительная скорость перемещения")

plt.ylim([0, 40])
plt.title("EEG power, body temperature and movement speed")
plt.ylabel(r"$t^o C$")
plt.xlabel("Time (Day)")
# plt.legend()

plt.subplot(2, 1, 2)

plt.plot(time_array[skip_end:], temp.dropna().iloc[skip_end:, -5], label="Body Temperature") 
plt.plot(time_array[skip_end:], temp.dropna().iloc[skip_end:, -2], label="Relative EEG Signal Power", color="C4")
plt.plot(time_array[skip_end:], temp.dropna().iloc[skip_end:, -1], label="Relative Movement Speed")

plt.ylim([0, 40])
# plt.title("Физиологические показатели крысы")
plt.ylabel(r"$t^o C$")
plt.xlabel("Time (Day)")
plt.legend()
plt.show()

# %%
time_array = temp.dropna().index/6/24

skip_start = 1250
skip_end = 1900

coef = 1e7

plt.subplot(2, 1, 1)

plt.plot(time_array[:skip_start], temp.dropna().iloc[:skip_start, -5], label="Body Temperature") 
plt.plot(time_array[:skip_start], temp.dropna().iloc[:skip_start, -4]*coef, label="Мощность ЭЭГ сигнала 1 - 4 Гц", color="C8")
plt.plot(time_array[:skip_start], temp.dropna().iloc[:skip_start, -3]*coef*10, label="Мощность ЭЭГ сигнала 4 - 8 Гц", color="C7")
# plt.plot(time_array[:skip_start], temp.dropna().iloc[:skip_start, -1], label="Скорость перемещения")

plt.ylim([0, 40])
plt.title("EEG power in two frequency bands and body temperature")
plt.ylabel(r"$t^o C$")
plt.xlabel("Time (Day)")
# plt.legend()

plt.subplot(2, 1, 2)

plt.plot(time_array[skip_end:], temp.dropna().iloc[skip_end:, -5], label="Body Temperature") 
plt.plot(time_array[skip_end:], temp.dropna().iloc[skip_end:, -4]*coef, label="Relative EEG power 1–4 Hz", color="C8")
plt.plot(time_array[skip_end:], temp.dropna().iloc[skip_end:, -3]*coef*10, label="Relative EEG power 4–8 Hz", color="C7")
# plt.plot(time_array[skip_end:], temp.dropna().iloc[skip_end:, -1], label="Скорость перемещения")

# plt.title("Физиологические показатели крысы")
plt.ylim([0, 40])
plt.ylabel(r"$t^o C$")
plt.xlabel("Time (Day)")
plt.legend()
plt.show()

# %%
time_array = temp.dropna().index/6/24

skip_start = 1250
skip_end = 1900

plt.subplot(2, 1, 1)

plt.plot(time_array[:skip_start], temp.dropna().iloc[:skip_start, -5], label="Body Temperature") 
plt.plot(time_array[:skip_start], temp.dropna().iloc[:skip_start, -3]*coef*10, label="EEG Signal Power 4 - 8 Hz", color="C7")
plt.plot(time_array[:skip_start], temp.dropna().iloc[:skip_start, -1], label="Relative Movement Speed", color="C1")

plt.title("Body temperature, movement speed and power of EEG 4 - 8 Hz")
plt.ylim([0, 40])
plt.ylabel(r"$t^o C$")
plt.xlabel("Time (Day)")
# plt.legend()

plt.subplot(2, 1, 2)

plt.plot(time_array[skip_end:], temp.dropna().iloc[skip_end:, -5], label="Body Temperature") 
plt.plot(time_array[skip_end:], temp.dropna().iloc[skip_end:, -3]*coef*10, label="Relative EEG Signal Power 4 - 8 Hz", color="C7")
plt.plot(time_array[skip_end:], temp.dropna().iloc[skip_end:, -1], label="Relative Movement Speed", color="C1")

# plt.title("Физиологические показатели крысы")
plt.ylim([0, 40])
plt.ylabel(r"$t^o C$")
plt.xlabel("Time (Day)")
plt.legend()
plt.show()

# %%
foo = lambda x: np.log(x)

x = foo(pd.concat([temp.dropna().iloc[:skip_start, -5], temp.dropna().iloc[skip_end:, -5]], axis=0))
y = foo(pd.concat([temp.dropna().iloc[:skip_start, -1], temp.dropna().iloc[skip_end:, -1]], axis=0))
o = np.ones(x.shape[0])

thx = 3.4
thy = -2

a = sum(o[(x < thx) & (y > thy)])
b = sum(o[(x > thx) & (y > thy)])
c = sum(o[(x < thx) & (y < thy)])
d = sum(o[(x > thx) & (y < thy)])

g, p, dof, expctd = chi2_contingency(np.array([[a, b], [c, d]]))

plt.axvline(x=thx, linestyle = "--",  label="Порог категории")
plt.axhline(y=thy, linestyle = "--")
sns.scatterplot(x=x, y=y)
plt.title("Температура тела и скорость перемещения \n (Критерий хи-квадрат = {}; P-value = {})".format(g, p))
plt.ylabel(r"$ln[v_{x}(t_0, T)]$")
plt.xlabel(r"$ln[t^o C]$")
plt
plt.show()

# %%
# TODO make an algorithm, that will count it for me

dec_begs = np.array([280, 600, 930, 2230, 2640, 3110])
dec_ends = np.array([400, 700, 1000, 2300, 2750, 3200])

inc_begs = np.array([440, 850, 1230, 2560, 3000])
inc_ends = np.array([460, 880, skip_start, 2590, 3030])

inc = pd.concat([temp.iloc[inc_begs[i]:inc_ends[i], :] for i in range(inc_begs.shape[0])], axis=0).dropna()
dec = pd.concat([temp.iloc[dec_begs[i]:dec_ends[i], :] for i in range(dec_begs.shape[0])], axis=0).dropna()

# %%
main = pd.concat([temp.dropna().iloc[:skip_start, :], temp.dropna().iloc[skip_end:, :]], axis=0)
main_wake = main[main["Temperature"] > 35]
main_sleep = main[main["Temperature"] < 15]

# %%
foo = lambda x : np.log(x)

sns.scatterplot(x=foo(main_wake.iloc[:, -5]), y=foo(main_wake.iloc[:, -1]), label="Norm", sizes=100)
sns.scatterplot(x=foo(main_sleep.iloc[:, -5]), y=foo(main_sleep.iloc[:, -1]), label="Torpor")
sns.scatterplot(x=foo(inc.iloc[:, -5]), y=foo(inc.iloc[:, -1]), label="Transition to norm")
sns.scatterplot(x=foo(dec.iloc[:, -5]), y=foo(dec.iloc[:, -1]), label="Transition to torpor")
plt.ylabel(r"$ln[v_{x}(t_0, T)]$")
plt.xlabel(r"$ln[t^o C]$")
plt.title("Body temperature and movement speed scatter plot")
plt.show()

# %%
foo = lambda x : np.log(x)

sns.scatterplot(x=foo(main_wake.iloc[:, -5]), y=foo(main_wake.iloc[:, -3]), label="Norm", sizes=100)
sns.scatterplot(x=foo(main_sleep.iloc[:, -5]), y=foo(main_sleep.iloc[:, -3]), label="Torpor")
sns.scatterplot(x=foo(inc.iloc[:, -5]), y=foo(inc.iloc[:, -3]), label="Transition to norm")
sns.scatterplot(x=foo(dec.iloc[:, -5]), y=foo(dec.iloc[:, -3]), label="Transition to torpor")
plt.ylabel(r"$ln[P(t_0, T)]_{4-8 Hz}$")
plt.xlabel(r"$ln[t^o C]$")
plt.title("Body temperature and EEG power 4 - 8 Hz scatter plot"

)
plt.show()

# %%
data = temp.copy()
data = pd.concat([data.iloc[:skip_start, :], data.iloc[skip_end:, :]], axis=0).dropna()

data["Температура"] = np.nan
data["Температура"][data["Temperature"] < 15] = "Ниже 15 градусов"
data["Температура"][data["Temperature"] > 35] = "Выше 35 градусов"

feature = ["Power 4 - 8 Hz", "Acceleration"]
rus_feature = [r"$ln[P(t_0, T)]_{4-8 Hz}$", r"$ln[V(t_0, T)]$"]

for i in range(2):
#     plt.subplot(1,2,i+1)
    data[feature[i]] = np.log(data[feature[i]])
    ans = wilcoxon(data[data["Температура"] == "Ниже 15 градусов"][feature[i]].sample(400), 
                   data[data["Температура"] == "Выше 35 градусов"][feature[i]].sample(400))
    
    dummy = round(ans[0], 2)
    print(ans[1])
    if ans[1] < 1e-10: 
        ans = [dummy, "< 1e-10"]
    else:
        ans = [dummy, "= {}".format(round(ans[1], 2))]
    
    sns.violinplot(x="Температура", y=feature[i], data=data, palette="Set2")
#     sns.swarmplot(x="Температура", y=feature[i], data=data, edgecolor="black", alpha=0.5)
    plt.title("Т = {}; P-value {}".format(ans[0], ans[1]))
    plt.xlabel(r"$t^o C$")
    plt.ylabel(rus_feature[i])
    plt.show()
# Out:
# /Users/wassilyminkow/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/wassilyminkow/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 1.1994681150382808e-38
# 4.479377889557819e-66

# %%
gap = 6*24  # set size of the rolling window 

x = np.log(temp.dropna().iloc[:, -5])  # temperature vector
y = np.log(temp.dropna().iloc[:, -3])  # power vector

p = np.zeros(x.shape[0]-gap) # p-value vector
c = np.zeros(x.shape[0]-gap) # statistic vector

# calculate the rolling corelation coefficient
for i in np.arange(x.shape[0]-gap):
    ans = pearsonr(x[i:i+gap], y[i:i+gap])
    c[i] = ans[0] 
    p[i] = ans[1]

# ajusting p-value with bonferroni method
p_adjusted = multipletests(p, method='bonferroni')[1]

c1 = np.zeros(x.shape[0]-gap)
c2 = np.zeros(x.shape[0]-gap)
c3 = np.zeros(x.shape[0]-gap)

c_green = np.zeros(x.shape[0]-gap)
c_yellow = np.zeros(x.shape[0]-gap)
c_red = np.zeros(x.shape[0]-gap)

c1[(p_adjusted < 0.05) & (np.abs(c) >= 0.9)] = 1
c2[(p_adjusted < 0.05) & (np.abs(c) >= 0.7) & (np.abs(c) < 0.9)] = 1
c3[(p_adjusted < 0.05) & (np.abs(c) >= 0.6) & (np.abs(c) < 0.7)] = 1
c1[c1 < 1] = 0
c2[c2 < 1] = 0
c3[c3 < 1] = 0

num = [c1, c2, c3]
col = [c_green, c_yellow, c_red]

z = list(zip(num, col))

counter = 0

for unit in z:
    for i in range(len(unit[0])):
        if unit[0][i] == 0:
            if counter == 0:
                unit[1][i] = NAN
            else:
                unit[1][i] = time_array[i]
                counter -= 1
        else:
            unit[1][i] = time_array[i]
            counter = gap

z[2][1][z[1][1] == 1] = nan
z[1][1][z[0][1] == 1] = nan
z[2][1][z[0][1] == 1] = nan

# %%
hight = 50

plt.subplot(2, 1, 1)
plt.title("Moving correlation of body temperature logarithm and EEG power 4 - 8 Hz logarithm\n (Window = 24 hours)")
plt.fill_between(z[2][1][:skip_start], np.ones(z[0][1][:skip_start].shape[0])*hight, alpha=0.5, facecolor="mistyrose", label = "70% > Pearson Absolute Correlation > 60%")
plt.fill_between(z[1][1][:skip_start], np.ones(z[0][1][:skip_start].shape[0])*hight, alpha=0.5, facecolor="lemonchiffon", label = "90% > Pearson Absolute Correlation > 70 %")
plt.fill_between(z[0][1][:skip_start], np.ones(z[0][1][:skip_start].shape[0])*hight, alpha=0.5, facecolor="lightgreen", label = "Pearson Absolute Correlation > 90 %")
plt.plot(time_array[:skip_start], temp.dropna().iloc[:skip_start, -5], label="Body Temperature")
plt.plot(time_array[:skip_start], temp.dropna().iloc[:skip_start, -3]*coef*10, label="Relative EEG Signal Power 4 - 8 Hz", color="C7")
plt.ylim([0,hight])
plt.ylabel(r"$t^o C$")
plt.xlabel("Time (Day)")

plt.subplot(2, 1, 2)
plt.fill_between(z[2][1][skip_end:], np.ones(z[0][1][skip_end:].shape[0])*hight, alpha=0.5, facecolor="mistyrose", label = "70% > Pearson Absolute Correlation > 60%")
plt.fill_between(z[1][1][skip_end:], np.ones(z[0][1][skip_end:].shape[0])*hight, alpha=0.5, facecolor="lemonchiffon", label = "90% > Pearson Absolute Correlation > 70 %")
plt.fill_between(z[0][1][skip_end:], np.ones(z[0][1][skip_end:].shape[0])*hight, alpha=0.5, facecolor="lightgreen", label = "Pearson Absolute Correlation > 90 %")
plt.plot(time_array[skip_end:], temp.dropna().iloc[skip_end:, -5], label="Body Temperature")
plt.plot(time_array[skip_end:], temp.dropna().iloc[skip_end:, -3]*coef*10, label="Relative EEG Signal Power 4 - 8 Hz", color="C7")
plt.ylim([0, hight])
plt.ylabel(r"$t^o C$")
plt.xlabel("Time (Day)")
plt.legend(prop={'size': 20})
plt.show()
