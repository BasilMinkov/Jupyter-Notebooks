# %%
import mne
import json
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.io import loadmat

# %matplotlib notebook

# %%
data_path = "/Users/vasilyminkov/Downloads/subject1/session1/eeg_200605191428_epochs.mat"
data = loadmat(data_path)

sfreq = 20
ch_names = data[0]['channels'][0:32]
ch_types = ['eeg'] * 32

df = np.array(data[0]['eeg']['trial 1'])[0:32,]

# %%
info = mne.create_info(ch_names=ch_names, sfreq=sfreq, ch_types=ch_types)
raw = mne.io.RawArray(df, info)
# Out:
# Creating RawArray with float64 data, n_channels=32, n_times=334848
#     Range : 0 ... 334847 =      0.000 ...   326.999 secs
# Ready.

# %%
scalings = {'eeg': 100}
raw.plot(n_channels=8, scalings=scalings)
# Out:
# <img src="data:image/png;base64,..." width="719">
# <img src="data:image/png;base64,..." width="719">

# %%
events = np.array(data["events"])

# %%
events
# Out:
# array([[2.0060e+03, 5.0000e+00, 1.9000e+01, 1.4000e+01, 2.7000e+01,
#         1.5744e+01],
#        [2.0060e+03, 5.0000e+00, 1.9000e+01, 1.4000e+01, 2.7000e+01,
#         1.6144e+01],
#        [2.0060e+03, 5.0000e+00, 1.9000e+01, 1.4000e+01, 2.7000e+01,
#         1.6545e+01],
#        [2.0060e+03, 5.0000e+00, 1.9000e+01, 1.4000e+01, 2.7000e+01,
#         1.6946e+01],
#        [2.0060e+03, 5.0000e+00, 1.9000e+01, 1.4000e+01, 2.7000e+01,
#         1.7346e+01],
#        [2.0060e+03, 5.0000e+00, 1.9000e+01, 1.4000e+01, 2.7000e+01,
#         1.7747e+01],
#        [2.0060e+03, 5.0000e+00, 1.9000e+01, 1.4000e+01, 2.7000e+01,
#         1.8147e+01],
#        [2.0060e+03, 5.0000e+00, 1.9000e+01, 1.4000e+01, 2.7000e+01,
#         1.8548e+01],
#        [2.0060e+03, 5.0000e+00, 1.9000e+01, 1.4000e+01, 2.7000e+01,
#         1.8948e+01],
#        [2.0060e+03, 5.0000e+00, 1.9000e+01, 1.4000e+01, 2.7000e+01,
#         1.9349e+01],
#        [2.0060e+03, 5.0000e+00, 1.9000e+01, 1.4000e+01, 2.7000e+01,
# ...
