# %%
import mne
import h5py
import matplotlib.pyplot as plt

# %%
control_path = "/Users/basilminkov/Neuroscience/Data/Test/15.02.17/Alpha_ada_control_02-15_21-23-09/experiment_data.h5"
exp_path = "/Users/basilminkov/Neuroscience/Data/Test/15.02.17/Alpha_ada_exp_02-15_21-04-23/experiment_data.h5"

control = h5py.File(control_path, 'r')
exp = h5py.File(exp_path, 'r')

control = control.get("protocol1/raw_data")
exp = exp.get("protocol1/raw_data")

# %%
plt.plot(control[:,])
plt.show()
